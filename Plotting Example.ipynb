# %%
from latex_figure import plotfigure
import numpy

# %%
x = numpy.linspace(0,100)
ys = numpy.array([x**2,x*2])
x = [x, x]

# %%
Linetypes = ['r-','g--']
x_label = 'Test Time'
y_label = 'Test Manipulation'

# %%
YNAMES = ['Square', 'Double']

# %%
aspect_ratio = 4 / 5
FULLSIZE = 5, 5 * aspect_ratio
HALFSIZE = 3, 3 * aspect_ratio

# %%
filename = "example Figure.pdf"

# %%
plotfigure(x, ys, YNAMES, Linetypes, x_label, y_label ,FULLSIZE, filename, diff=False, legend=True)
